# %%
from helper.py import ik_optim
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from helper.py import ik_optim
#
# ModuleNotFoundError: No module named 'helper'
